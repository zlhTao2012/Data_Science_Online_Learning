# %%
import graphlab
import numpy as np
import random

# %%
def output_func(x1, x2, slope, point):
    output = slope*x1 - slope*point[0] + point[1] - x2
    return output

# %%
def Simple_PLA (N):
    max_run = 1000 # No. of repeat the experiment
    N = N # sample data size
    correct_target = N # no. of correct target to converge 
    
    run = 0 # track the run number, inital 
    iter_success_list = list() # track the succssfully converged iteration no. in each run
    prediction_results = list() # track the relationship between f and g to calculate P[f(x) != g(x)]

    while run < max_run:

        # Generate data 
        features_1 = np.array(([[1]]*N))
        features_2 = np.array((np.random.uniform(-1, 1., size=(N, 2)))) # generating two random, uniformly distributed points in [-1, 1]
        features = np.hstack((features_1, features_2))

        function_f_points = np.array((np.random.uniform(-1, 1., size=(2, 2))))    
    
        # Calculate the slope
        slope = (function_f_points[1,1] - function_f_points[0,1])/(function_f_points[1,0] - function_f_points[0,0])
    
        # Calculate the output
        output = output_func(features_2[:,0], features_2[:,1], slope, function_f_points[0,:])
        #output = graphlab.SArray(map(lambda number: +1. if number >= 0 else -1., output))
        output = graphlab.SArray(np.sign(output))
        
        # inital values for each run
        iteration = 0 # track the iteration number
        weights=[0,0,0] # initial vector weights
        errors = [0]*N # inital errors

        while sum(errors) < correct_target:

            # Calculate the sign of predictions
            #predictions = graphlab.SArray(map(lambda number: +1. if number >= 0 else -1., np.dot(features, weights)))
            predictions = graphlab.SArray(np.sign(np.dot(features, weights)))
            
            # compare the prediction with output
            errors = graphlab.SArray(predictions == output)       
            #print "iteration " + str(iteration) + ": " + str(sum(errors)) + " correct predictions."


            misclassified_points = list() # track the misclassifed points index
            mis_points = list() # track the misclassfied points

            for num in xrange(N):
                if errors[num] == 0:
                    misclassified_points.append(num)
                    mis_points.append(features[num,:])

            if sum(errors) < correct_target:

                # Randomly choose one point from misclassified points (choose index in here) 
                misclassified_point = random.choice(misclassified_points)

                # Recalculate the weights
                weights += features[misclassified_point, :] * output[misclassified_point]

            else:

                iter_success_list.append(iteration) # include the successfully converged iteration number
                run += 1 # update the run number

                features_3 = np.array((np.random.uniform(-1, 1., size=(1, 2)))) # generate a random point

                
                # Target function classify the random point
                target_f = output_func(features_3[:,0], features_3[:,1], slope, function_f_points[0,:])
                #target_f = graphlab.SArray(map(lambda number: +1. if number >= 0 else -1., target_f))
                target_f = graphlab.SArray(np.sign(target_f))

                # predicted function classify the random point
                predict_g = weights[0] + weights[1]*features_3[:,0] + weights[2]*features_3[:,1]
                #predict_g = graphlab.SArray(map(lambda number: +1. if number >= 0 else -1., predict_g))                
                predict_g = graphlab.SArray(np.sign(predict_g))
                

                # include the compared classification result of the random point
                prediction_results.append(predict_g == target_f)

                print "Run #" + str(run) + ": " + "successfully converged @ iteration: " + str(iteration)
                print "Weights: " + str(weights)
                print "Target/Predicted function agree: " + str(list(predict_g) == list(target_f))
                print "======================================================================"
                break

            iteration += 1

    # Calculate the average iteration        
    avg_iter = sum(iter_success_list) / len(iter_success_list)
    disagree_prob = 1- sum(prediction_results) / float(len(prediction_results))
    
    print "Avg. iteration to succussfully converged: " + str(avg_iter)
    print "Probabily that f and g will disagree on their classfication of a random point: " + '{:.4f}'.format(round(disagree_prob[0], 4))

# %%
Simple_PLA(N = 10)
# Out:
# Run #1: successfully converged @ iteration: 2
# Weights: [ 0.          0.41507224 -0.97989599]
# Target/Predicted function agree: True
# ======================================================================
# Run #2: successfully converged @ iteration: 4
# Weights: [ 0.          2.1860499  -0.49746654]
# Target/Predicted function agree: False
# ======================================================================
# Run #3: successfully converged @ iteration: 5
# Weights: [ 1.         -0.111277   -1.33147146]
# Target/Predicted function agree: True
# ======================================================================
# Run #4: successfully converged @ iteration: 2
# Weights: [ 0.         -1.2455353   0.27161848]
# Target/Predicted function agree: True
# ======================================================================
# Run #5: successfully converged @ iteration: 6
# Weights: [ 0.          2.26199709 -1.1825735 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #6: successfully converged @ iteration: 1
# Weights: [-1.         -0.23920888 -0.92816079]
# Target/Predicted function agree: True
# ======================================================================
# Run #7: successfully converged @ iteration: 10
# Weights: [ 0.          2.33880114 -0.79736686]
# Target/Predicted function agree: True
# ======================================================================
# Run #8: successfully converged @ iteration: 5
# Weights: [ 1.         -0.70278644 -1.74323686]
# Target/Predicted function agree: True
# ======================================================================
# Run #9: successfully converged @ iteration: 3
# Weights: [-1.         -1.63191478 -1.25655267]
# Target/Predicted function agree: True
# ======================================================================
# Run #10: successfully converged @ iteration: 3
# Weights: [-1.         -1.75546305  0.13015058]
# Target/Predicted function agree: False
# ======================================================================
# Run #11: successfully converged @ iteration: 4
# Weights: [ 0.          1.60689788 -0.7893869 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #12: successfully converged @ iteration: 20
# Weights: [ 2.         -0.25159795 -2.66662091]
# Target/Predicted function agree: True
# ======================================================================
# Run #13: successfully converged @ iteration: 5
# Weights: [ 1.         -0.62094136 -2.01777007]
# Target/Predicted function agree: True
# ======================================================================
# Run #14: successfully converged @ iteration: 15
# Weights: [-1.          3.55717696  0.36139871]
# Target/Predicted function agree: True
# ======================================================================
# Run #15: successfully converged @ iteration: 2
# Weights: [ 0.         -0.27544652 -0.27647141]
# Target/Predicted function agree: True
# ======================================================================
# Run #16: successfully converged @ iteration: 6
# Weights: [ 0.          1.27138901  0.05712449]
# Target/Predicted function agree: True
# ======================================================================
# Run #17: successfully converged @ iteration: 3
# Weights: [ 1.         -1.29994153  0.07069538]
# Target/Predicted function agree: True
# ======================================================================
# Run #18: successfully converged @ iteration: 1
# Weights: [-1.         -0.07159558 -0.61923318]
# Target/Predicted function agree: True
# ======================================================================
# Run #19: successfully converged @ iteration: 2
# Weights: [ 0.          1.07950741 -1.10500692]
# Target/Predicted function agree: True
# ======================================================================
# Run #20: successfully converged @ iteration: 5
# Weights: [ 1.          0.89377741 -1.73258793]
# Target/Predicted function agree: True
# ======================================================================
# Run #21: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #22: successfully converged @ iteration: 17
# Weights: [ 1.         -3.40808763 -1.02730963]
# Target/Predicted function agree: False
# ======================================================================
# Run #23: successfully converged @ iteration: 19
# Weights: [ 1.         -3.15253371 -0.67523679]
# Target/Predicted function agree: True
# ======================================================================
# Run #24: successfully converged @ iteration: 1
# Weights: [-1.         -0.54273224 -0.37051976]
# Target/Predicted function agree: True
# ======================================================================
# Run #25: successfully converged @ iteration: 2
# Weights: [ 0.         -0.1840568  -1.00089327]
# Target/Predicted function agree: True
# ======================================================================
# Run #26: successfully converged @ iteration: 4
# Weights: [ 0.          1.32204924 -0.58369994]
# Target/Predicted function agree: True
# ======================================================================
# Run #27: successfully converged @ iteration: 14
# Weights: [-2.         -0.35079477 -2.87540822]
# Target/Predicted function agree: True
# ======================================================================
# Run #28: successfully converged @ iteration: 4
# Weights: [ 0.         -1.39077659 -1.53299655]
# Target/Predicted function agree: True
# ======================================================================
# Run #29: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #30: successfully converged @ iteration: 32
# Weights: [-2.         -0.99033194 -4.41314318]
# Target/Predicted function agree: True
# ======================================================================
# Run #31: successfully converged @ iteration: 6
# Weights: [ 0.         -1.54133647 -1.11933111]
# Target/Predicted function agree: True
# ======================================================================
# Run #32: successfully converged @ iteration: 2
# Weights: [ 0.          0.49173003 -0.45447757]
# Target/Predicted function agree: True
# ======================================================================
# Run #33: successfully converged @ iteration: 7
# Weights: [ 1.          0.19204686 -1.62242668]
# Target/Predicted function agree: True
# ======================================================================
# Run #34: successfully converged @ iteration: 6
# Weights: [ 0.         -1.149662   -1.83429822]
# Target/Predicted function agree: True
# ======================================================================
# Run #35: successfully converged @ iteration: 5
# Weights: [-1.          0.94842697 -1.27037066]
# Target/Predicted function agree: True
# ======================================================================
# Run #36: successfully converged @ iteration: 3
# Weights: [-1.         -0.29568865 -1.68867293]
# Target/Predicted function agree: True
# ======================================================================
# Run #37: successfully converged @ iteration: 6
# Weights: [ 0.         -0.96552621 -2.01136545]
# Target/Predicted function agree: True
# ======================================================================
# Run #38: successfully converged @ iteration: 9
# Weights: [ 1.         -0.63853544 -2.16439238]
# Target/Predicted function agree: True
# ======================================================================
# Run #39: successfully converged @ iteration: 3
# Weights: [-1.          1.25448785  0.07116282]
# Target/Predicted function agree: True
# ======================================================================
# Run #40: successfully converged @ iteration: 14
# Weights: [ 0.         -1.82774137 -2.43675237]
# Target/Predicted function agree: False
# ======================================================================
# Run #41: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #42: successfully converged @ iteration: 7
# Weights: [-1.         -1.86892922 -0.33154608]
# Target/Predicted function agree: True
# ======================================================================
# Run #43: successfully converged @ iteration: 4
# Weights: [ 0.          0.16417691 -2.20213219]
# Target/Predicted function agree: True
# ======================================================================
# Run #44: successfully converged @ iteration: 14
# Weights: [ 2.         -2.62777262 -1.93542497]
# Target/Predicted function agree: True
# ======================================================================
# Run #45: successfully converged @ iteration: 5
# Weights: [ 1.         -1.18251256 -1.31552031]
# Target/Predicted function agree: True
# ======================================================================
# Run #46: successfully converged @ iteration: 10
# Weights: [ 2.          0.6714734  -1.97317463]
# Target/Predicted function agree: True
# ======================================================================
# Run #47: successfully converged @ iteration: 15
# Weights: [ 1.          2.36976739 -1.54763343]
# Target/Predicted function agree: True
# ======================================================================
# Run #48: successfully converged @ iteration: 11
# Weights: [-1.          0.98943482 -2.44013476]
# Target/Predicted function agree: True
# ======================================================================
# Run #49: successfully converged @ iteration: 13
# Weights: [-1.          1.95565494 -2.0843689 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #50: successfully converged @ iteration: 3
# Weights: [-1.         -1.31965292 -0.75412752]
# Target/Predicted function agree: True
# ======================================================================
# Run #51: successfully converged @ iteration: 13
# Weights: [-1.         -1.57918549 -2.65662706]
# Target/Predicted function agree: True
# ======================================================================
# Run #52: successfully converged @ iteration: 1
# Weights: [-1.         -0.80595774 -0.77798005]
# Target/Predicted function agree: True
# ======================================================================
# Run #53: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: False
# ======================================================================
# Run #54: successfully converged @ iteration: 17
# Weights: [-1.         -2.75384527 -1.04247691]
# Target/Predicted function agree: True
# ======================================================================
# Run #55: successfully converged @ iteration: 7
# Weights: [-1.          2.37714402 -0.15632122]
# Target/Predicted function agree: True
# ======================================================================
# Run #56: successfully converged @ iteration: 11
# Weights: [-1.         -2.39536304 -1.38855711]
# Target/Predicted function agree: True
# ======================================================================
# Run #57: successfully converged @ iteration: 1
# Weights: [-1.          0.16902618 -0.83594077]
# Target/Predicted function agree: True
# ======================================================================
# Run #58: successfully converged @ iteration: 5
# Weights: [ 1.         -0.75744054 -1.54621247]
# Target/Predicted function agree: True
# ======================================================================
# Run #59: successfully converged @ iteration: 17
# Weights: [-1.         -0.93174574 -3.20716097]
# Target/Predicted function agree: True
# ======================================================================
# Run #60: successfully converged @ iteration: 7
# Weights: [-1.          2.45255027 -0.88352899]
# Target/Predicted function agree: True
# ======================================================================
# Run #61: successfully converged @ iteration: 5
# Weights: [-1.         -0.04992648 -1.44861147]
# Target/Predicted function agree: True
# ======================================================================
# Run #62: successfully converged @ iteration: 256
# Weights: [-2.         -5.57358751 -6.51370806]
# Target/Predicted function agree: True
# ======================================================================
# Run #63: successfully converged @ iteration: 12
# Weights: [-2.         -2.4389225  -0.60989661]
# Target/Predicted function agree: True
# ======================================================================
# Run #64: successfully converged @ iteration: 7
# Weights: [ 1.          1.66977267  0.16099364]
# Target/Predicted function agree: True
# ======================================================================
# Run #65: successfully converged @ iteration: 3
# Weights: [-1.          1.04413499 -1.16486944]
# Target/Predicted function agree: True
# ======================================================================
# Run #66: successfully converged @ iteration: 5
# Weights: [-1.         -0.16557276 -1.241452  ]
# Target/Predicted function agree: True
# ======================================================================
# Run #67: successfully converged @ iteration: 1
# Weights: [-1.         -0.58945608  0.04891512]
# Target/Predicted function agree: True
# ======================================================================
# Run #68: successfully converged @ iteration: 5
# Weights: [-1.          0.84549909 -1.05731237]
# Target/Predicted function agree: True
# ======================================================================
# Run #69: successfully converged @ iteration: 4
# Weights: [ 0.          0.51122233 -1.30604744]
# Target/Predicted function agree: True
# ======================================================================
# Run #70: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #71: successfully converged @ iteration: 9
# Weights: [-1.          0.82128646 -1.7666234 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #72: successfully converged @ iteration: 3
# Weights: [-1.          1.16956656 -1.24479966]
# Target/Predicted function agree: True
# ======================================================================
# Run #73: successfully converged @ iteration: 3
# Weights: [-1.          1.4200975  -1.40765558]
# Target/Predicted function agree: True
# ======================================================================
# Run #74: successfully converged @ iteration: 12
# Weights: [ 0.          1.19705504 -3.17680979]
# Target/Predicted function agree: True
# ======================================================================
# Run #75: successfully converged @ iteration: 8
# Weights: [ 0.         -2.22242547 -0.0039638 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #76: successfully converged @ iteration: 7
# Weights: [ 1.          1.42410196 -0.89192265]
# Target/Predicted function agree: True
# ======================================================================
# Run #77: successfully converged @ iteration: 7
# Weights: [ 1.         -1.73913924 -1.25710884]
# Target/Predicted function agree: True
# ======================================================================
# Run #78: successfully converged @ iteration: 4
# Weights: [ 0.          1.81218919 -0.7376158 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #79: successfully converged @ iteration: 4
# Weights: [ 0.         -1.02807807 -1.33674844]
# Target/Predicted function agree: True
# ======================================================================
# Run #80: successfully converged @ iteration: 7
# Weights: [ 1.          0.38493474 -1.41669566]
# Target/Predicted function agree: True
# ======================================================================
# Run #81: successfully converged @ iteration: 2
# Weights: [ 0.          0.75499489  0.22469991]
# Target/Predicted function agree: True
# ======================================================================
# Run #82: successfully converged @ iteration: 24
# Weights: [ 2.          1.27860009 -2.2142355 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #83: successfully converged @ iteration: 11
# Weights: [-1.          2.22703371  0.43878675]
# Target/Predicted function agree: True
# ======================================================================
# Run #84: successfully converged @ iteration: 52
# Weights: [ 2.          3.36739043 -2.06127652]
# Target/Predicted function agree: True
# ======================================================================
# Run #85: successfully converged @ iteration: 17
# Weights: [ 1.         -1.50995561 -2.42304505]
# Target/Predicted function agree: True
# ======================================================================
# Run #86: successfully converged @ iteration: 2
# Weights: [ 0.          1.50626966 -1.13735956]
# Target/Predicted function agree: True
# ======================================================================
# Run #87: successfully converged @ iteration: 25
# Weights: [-1.         -3.16968613 -3.89702384]
# Target/Predicted function agree: True
# ======================================================================
# Run #88: successfully converged @ iteration: 25
# Weights: [-1.         -0.30817818 -3.46081511]
# Target/Predicted function agree: False
# ======================================================================
# Run #89: successfully converged @ iteration: 6
# Weights: [ 0.         -1.89892454 -0.18892969]
# Target/Predicted function agree: True
# ======================================================================
# Run #90: successfully converged @ iteration: 21
# Weights: [-1.          3.71062858 -0.71671121]
# Target/Predicted function agree: True
# ======================================================================
# Run #91: successfully converged @ iteration: 11
# Weights: [-1.         -1.6380578  -1.34237024]
# Target/Predicted function agree: True
# ======================================================================
# Run #92: successfully converged @ iteration: 53
# Weights: [ 1.          3.94890591 -2.01854235]
# Target/Predicted function agree: True
# ======================================================================
# Run #93: successfully converged @ iteration: 5
# Weights: [-1.          0.02642465 -1.3873246 ]
# Target/Predicted function agree: False
# ======================================================================
# Run #94: successfully converged @ iteration: 10
# Weights: [ 0.          1.09761261 -2.34268163]
# Target/Predicted function agree: True
# ======================================================================
# Run #95: successfully converged @ iteration: 4
# Weights: [ 0.          1.32314952 -0.51634757]
# Target/Predicted function agree: True
# ======================================================================
# Run #96: successfully converged @ iteration: 5
# Weights: [ 1.          1.78843765 -0.71642212]
# Target/Predicted function agree: True
# ======================================================================
# Run #97: successfully converged @ iteration: 4
# Weights: [ 0.         -1.81668666 -0.42167888]
# Target/Predicted function agree: True
# ======================================================================
# Run #98: successfully converged @ iteration: 15
# Weights: [-1.          2.37994352 -2.44105762]
# Target/Predicted function agree: True
# ======================================================================
# Run #99: successfully converged @ iteration: 25
# Weights: [-1.          1.8714805  -3.33126903]
# Target/Predicted function agree: True
# ======================================================================
# Run #100: successfully converged @ iteration: 2
# Weights: [ 0.          1.35981557 -0.74897442]
# Target/Predicted function agree: True
# ======================================================================
# Run #101: successfully converged @ iteration: 14
# Weights: [ 0.          2.44642052 -2.29842125]
# Target/Predicted function agree: True
# ======================================================================
# Run #102: successfully converged @ iteration: 5
# Weights: [ 1.         -1.03426787 -0.88997626]
# Target/Predicted function agree: True
# ======================================================================
# Run #103: successfully converged @ iteration: 15
# Weights: [-1.          1.76055037 -2.37272066]
# Target/Predicted function agree: True
# ======================================================================
# Run #104: successfully converged @ iteration: 8
# Weights: [ 0.          1.89856816 -1.56951569]
# Target/Predicted function agree: False
# ======================================================================
# Run #105: successfully converged @ iteration: 3
# Weights: [-1.          0.6347937  -1.34262814]
# Target/Predicted function agree: True
# ======================================================================
# Run #106: successfully converged @ iteration: 2
# Weights: [ 0.          0.6044293  -0.62859205]
# Target/Predicted function agree: True
# ======================================================================
# Run #107: successfully converged @ iteration: 4
# Weights: [ 0.          2.02518734 -1.2376115 ]
# Target/Predicted function agree: False
# ======================================================================
# Run #108: successfully converged @ iteration: 8
# Weights: [ 0.          2.39816968 -1.90320048]
# Target/Predicted function agree: False
# ======================================================================
# Run #109: successfully converged @ iteration: 3
# Weights: [ 1.         -1.56119924 -0.69348371]
# Target/Predicted function agree: True
# ======================================================================
# Run #110: successfully converged @ iteration: 6
# Weights: [ 0.          2.33969936 -0.22569444]
# Target/Predicted function agree: True
# ======================================================================
# Run #111: successfully converged @ iteration: 19
# Weights: [ 1.          3.77408695 -1.64262425]
# Target/Predicted function agree: True
# ======================================================================
# Run #112: successfully converged @ iteration: 1
# Weights: [-1.         -0.60185066  0.18502819]
# Target/Predicted function agree: True
# ======================================================================
# Run #113: successfully converged @ iteration: 4
# Weights: [ 0.         -0.9196439  -1.39868795]
# Target/Predicted function agree: True
# ======================================================================
# Run #114: successfully converged @ iteration: 3
# Weights: [ 1.         0.6697895 -1.4071243]
# Target/Predicted function agree: True
# ======================================================================
# Run #115: successfully converged @ iteration: 17
# Weights: [ 1.         -1.88207744 -2.9804919 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #116: successfully converged @ iteration: 4
# Weights: [ 0.         -1.35309852 -0.61131096]
# Target/Predicted function agree: True
# ======================================================================
# Run #117: successfully converged @ iteration: 7
# Weights: [-1.         -1.19564714 -1.67534425]
# Target/Predicted function agree: True
# ======================================================================
# Run #118: successfully converged @ iteration: 8
# Weights: [ 0.         -2.58402869 -1.35865511]
# Target/Predicted function agree: True
# ======================================================================
# Run #119: successfully converged @ iteration: 13
# Weights: [-1.         -2.27628385  1.22731956]
# Target/Predicted function agree: True
# ======================================================================
# Run #120: successfully converged @ iteration: 16
# Weights: [-2.          1.46351459 -2.25927323]
# Target/Predicted function agree: True
# ======================================================================
# Run #121: successfully converged @ iteration: 2
# Weights: [ 0.          1.27912713 -1.05059887]
# Target/Predicted function agree: True
# ======================================================================
# Run #122: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #123: successfully converged @ iteration: 9
# Weights: [ 1.         -2.01567414 -0.07588767]
# Target/Predicted function agree: True
# ======================================================================
# Run #124: successfully converged @ iteration: 11
# Weights: [ 1.          2.74288646 -0.60858862]
# Target/Predicted function agree: True
# ======================================================================
# Run #125: successfully converged @ iteration: 10
# Weights: [ 0.         -1.53396181 -2.26087815]
# Target/Predicted function agree: True
# ======================================================================
# Run #126: successfully converged @ iteration: 9
# Weights: [ 1.         -2.23312742 -1.16324767]
# Target/Predicted function agree: True
# ======================================================================
# Run #127: successfully converged @ iteration: 2
# Weights: [ 0.         -0.98623081 -0.42566049]
# Target/Predicted function agree: False
# ======================================================================
# Run #128: successfully converged @ iteration: 4
# Weights: [ 0.          0.38949152 -2.30982009]
# Target/Predicted function agree: True
# ======================================================================
# Run #129: successfully converged @ iteration: 2
# Weights: [ 0.         -0.48619996 -0.57084241]
# Target/Predicted function agree: True
# ======================================================================
# Run #130: successfully converged @ iteration: 5
# Weights: [-1.          0.54025491 -1.5508583 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #131: successfully converged @ iteration: 11
# Weights: [-1.          2.47108568 -0.16868761]
# Target/Predicted function agree: True
# ======================================================================
# Run #132: successfully converged @ iteration: 7
# Weights: [-1.          0.66534017 -1.93237031]
# Target/Predicted function agree: True
# ======================================================================
# Run #133: successfully converged @ iteration: 3
# Weights: [ 1.          0.5165403  -1.57250962]
# Target/Predicted function agree: True
# ======================================================================
# Run #134: successfully converged @ iteration: 14
# Weights: [ 0.          0.74688577 -2.62813778]
# Target/Predicted function agree: False
# ======================================================================
# Run #135: successfully converged @ iteration: 1
# Weights: [-1.         -0.24506672 -0.93118609]
# Target/Predicted function agree: True
# ======================================================================
# Run #136: successfully converged @ iteration: 2
# Weights: [ 0.          1.11312114 -1.49199474]
# Target/Predicted function agree: True
# ======================================================================
# Run #137: successfully converged @ iteration: 7
# Weights: [ 1.          1.57982101 -0.58235273]
# Target/Predicted function agree: True
# ======================================================================
# Run #138: successfully converged @ iteration: 4
# Weights: [ 0.         -0.888472   -2.23698929]
# Target/Predicted function agree: True
# ======================================================================
# Run #139: successfully converged @ iteration: 4
# Weights: [ 0.         -2.27884659 -0.75319249]
# Target/Predicted function agree: True
# ======================================================================
# Run #140: successfully converged @ iteration: 9
# Weights: [-1.          1.98181006 -1.12632752]
# Target/Predicted function agree: True
# ======================================================================
# Run #141: successfully converged @ iteration: 9
# Weights: [-1.          2.31048283 -0.9754221 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #142: successfully converged @ iteration: 5
# Weights: [-1.         -1.73800284 -0.51673519]
# Target/Predicted function agree: True
# ======================================================================
# Run #143: successfully converged @ iteration: 25
# Weights: [ 1.         -0.43852584 -3.94655725]
# Target/Predicted function agree: True
# ======================================================================
# Run #144: successfully converged @ iteration: 9
# Weights: [ 1.          2.14768706 -0.26723141]
# Target/Predicted function agree: False
# ======================================================================
# Run #145: successfully converged @ iteration: 15
# Weights: [ 1.         -2.6542892  -2.13205055]
# Target/Predicted function agree: True
# ======================================================================
# Run #146: successfully converged @ iteration: 4
# Weights: [ 0.         -1.96795319  0.27372139]
# Target/Predicted function agree: True
# ======================================================================
# Run #147: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #148: successfully converged @ iteration: 7
# Weights: [-1.         -1.64637492 -0.24904807]
# Target/Predicted function agree: True
# ======================================================================
# Run #149: successfully converged @ iteration: 1
# Weights: [-1.         -0.69704491 -0.98242695]
# Target/Predicted function agree: True
# ======================================================================
# Run #150: successfully converged @ iteration: 3
# Weights: [ 1.          1.41654955 -0.6337856 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #151: successfully converged @ iteration: 27
# Weights: [-1.          2.89780591 -2.50773553]
# Target/Predicted function agree: True
# ======================================================================
# Run #152: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #153: successfully converged @ iteration: 6
# Weights: [ 0.          0.95866265 -0.38301371]
# Target/Predicted function agree: True
# ======================================================================
# Run #154: successfully converged @ iteration: 4
# Weights: [ 0.          0.83808474 -1.78549528]
# Target/Predicted function agree: True
# ======================================================================
# Run #155: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #156: successfully converged @ iteration: 8
# Weights: [ 0.          2.72660225  0.38714405]
# Target/Predicted function agree: True
# ======================================================================
# Run #157: successfully converged @ iteration: 9
# Weights: [ 1.         -1.70057644 -1.82645473]
# Target/Predicted function agree: True
# ======================================================================
# Run #158: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: False
# ======================================================================
# Run #159: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #160: successfully converged @ iteration: 5
# Weights: [-1.          0.6468692  -1.78363353]
# Target/Predicted function agree: True
# ======================================================================
# Run #161: successfully converged @ iteration: 25
# Weights: [ 1.         -3.15720156 -2.07552571]
# Target/Predicted function agree: True
# ======================================================================
# Run #162: successfully converged @ iteration: 9
# Weights: [ 1.          1.71494559 -0.70492453]
# Target/Predicted function agree: True
# ======================================================================
# Run #163: successfully converged @ iteration: 9
# Weights: [ 1.          1.79406235 -1.91654514]
# Target/Predicted function agree: True
# ======================================================================
# Run #164: successfully converged @ iteration: 6
# Weights: [ 0.          1.55495498 -0.92870363]
# Target/Predicted function agree: True
# ======================================================================
# Run #165: successfully converged @ iteration: 3
# Weights: [-1.         -0.81861519 -1.50656198]
# Target/Predicted function agree: True
# ======================================================================
# Run #166: successfully converged @ iteration: 302
# Weights: [-2.          3.59631727 -3.46288679]
# Target/Predicted function agree: True
# ======================================================================
# Run #167: successfully converged @ iteration: 3
# Weights: [-1.         -1.14994135 -0.36215294]
# Target/Predicted function agree: True
# ======================================================================
# Run #168: successfully converged @ iteration: 12
# Weights: [ 0.         -2.09353775 -2.12590873]
# Target/Predicted function agree: True
# ======================================================================
# Run #169: successfully converged @ iteration: 38
# Weights: [ 2.         -3.39020987 -0.71586766]
# Target/Predicted function agree: True
# ======================================================================
# Run #170: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #171: successfully converged @ iteration: 2
# Weights: [ 0.         -1.22999369  0.44519308]
# Target/Predicted function agree: True
# ======================================================================
# Run #172: successfully converged @ iteration: 17
# Weights: [ 1.         -1.67055854 -2.55311102]
# Target/Predicted function agree: True
# ======================================================================
# Run #173: successfully converged @ iteration: 7
# Weights: [-1.         -1.28214005 -1.24538083]
# Target/Predicted function agree: True
# ======================================================================
# Run #174: successfully converged @ iteration: 4
# Weights: [ 0.         -1.33986373 -1.61846504]
# Target/Predicted function agree: True
# ======================================================================
# Run #175: successfully converged @ iteration: 7
# Weights: [-1.          1.29799368 -2.16381134]
# Target/Predicted function agree: True
# ======================================================================
# Run #176: successfully converged @ iteration: 5
# Weights: [ 1.          1.59723205 -1.6140251 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #177: successfully converged @ iteration: 10
# Weights: [ 2.          1.84822334 -0.72059658]
# Target/Predicted function agree: False
# ======================================================================
# Run #178: successfully converged @ iteration: 7
# Weights: [ 1.         -1.2547806  -1.95627721]
# Target/Predicted function agree: True
# ======================================================================
# Run #179: successfully converged @ iteration: 1
# Weights: [-1.          0.50014786  0.86162215]
# Target/Predicted function agree: True
# ======================================================================
# Run #180: successfully converged @ iteration: 14
# Weights: [ 2.          2.71726994 -1.53020924]
# Target/Predicted function agree: True
# ======================================================================
# Run #181: successfully converged @ iteration: 6
# Weights: [ 0.         -2.23417399 -0.77485858]
# Target/Predicted function agree: True
# ======================================================================
# Run #182: successfully converged @ iteration: 28
# Weights: [ 2.         -0.88430889 -2.96705252]
# Target/Predicted function agree: True
# ======================================================================
# Run #183: successfully converged @ iteration: 1
# Weights: [-1.          0.88243175 -0.60551836]
# Target/Predicted function agree: True
# ======================================================================
# Run #184: successfully converged @ iteration: 6
# Weights: [ 0.          0.00484778 -1.6994899 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #185: successfully converged @ iteration: 7
# Weights: [ 1.          1.27270343 -2.42966352]
# Target/Predicted function agree: False
# ======================================================================
# Run #186: successfully converged @ iteration: 14
# Weights: [ 0.          3.04536279 -0.62358582]
# Target/Predicted function agree: True
# ======================================================================
# Run #187: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #188: successfully converged @ iteration: 6
# Weights: [ 0.          0.83630285 -1.24766314]
# Target/Predicted function agree: True
# ======================================================================
# Run #189: successfully converged @ iteration: 5
# Weights: [-1.         -0.8433411  -1.39544196]
# Target/Predicted function agree: True
# ======================================================================
# Run #190: successfully converged @ iteration: 2
# Weights: [ 0.          0.78981898 -0.52616112]
# Target/Predicted function agree: True
# ======================================================================
# Run #191: successfully converged @ iteration: 2
# Weights: [ 0.         -0.34467626 -1.11617115]
# Target/Predicted function agree: True
# ======================================================================
# Run #192: successfully converged @ iteration: 13
# Weights: [-1.          1.05519167 -1.82812872]
# Target/Predicted function agree: True
# ======================================================================
# Run #193: successfully converged @ iteration: 25
# Weights: [ 1.         -1.54994542 -2.07195541]
# Target/Predicted function agree: True
# ======================================================================
# Run #194: successfully converged @ iteration: 2
# Weights: [ 0.          1.75450147  0.49167018]
# Target/Predicted function agree: True
# ======================================================================
# Run #195: successfully converged @ iteration: 2
# Weights: [ 0.         -1.38849576 -0.65958132]
# Target/Predicted function agree: True
# ======================================================================
# Run #196: successfully converged @ iteration: 17
# Weights: [ 1.          3.43779401 -0.53461285]
# Target/Predicted function agree: True
# ======================================================================
# Run #197: successfully converged @ iteration: 4
# Weights: [ 0.          0.75920961 -2.26053542]
# Target/Predicted function agree: True
# ======================================================================
# Run #198: successfully converged @ iteration: 7
# Weights: [-1.         -1.61688899 -0.80436582]
# Target/Predicted function agree: False
# ======================================================================
# Run #199: successfully converged @ iteration: 7
# Weights: [ 1.         -1.8368556  -0.01601368]
# Target/Predicted function agree: True
# ======================================================================
# Run #200: successfully converged @ iteration: 5
# Weights: [-1.          1.09248912 -1.69997309]
# Target/Predicted function agree: False
# ======================================================================
# Run #201: successfully converged @ iteration: 2
# Weights: [ 0.         -0.2986431  -0.47824431]
# Target/Predicted function agree: False
# ======================================================================
# Run #202: successfully converged @ iteration: 5
# Weights: [ 1.          1.83663978 -0.44103004]
# Target/Predicted function agree: True
# ======================================================================
# Run #203: successfully converged @ iteration: 3
# Weights: [ 1.          1.77922692 -0.1899501 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #204: successfully converged @ iteration: 1
# Weights: [-1.         -0.28036337 -0.77429703]
# Target/Predicted function agree: False
# ======================================================================
# Run #205: successfully converged @ iteration: 9
# Weights: [ 1.          1.98905211 -0.90944953]
# Target/Predicted function agree: True
# ======================================================================
# Run #206: successfully converged @ iteration: 11
# Weights: [ 1.          3.01211264 -0.82255803]
# Target/Predicted function agree: True
# ======================================================================
# Run #207: successfully converged @ iteration: 14
# Weights: [-2.         -1.44114642 -2.50627552]
# Target/Predicted function agree: True
# ======================================================================
# Run #208: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #209: successfully converged @ iteration: 4
# Weights: [ 0.          0.0810505  -1.37606378]
# Target/Predicted function agree: True
# ======================================================================
# Run #210: successfully converged @ iteration: 4
# Weights: [ 0.          0.64233124 -1.77101914]
# Target/Predicted function agree: True
# ======================================================================
# Run #211: successfully converged @ iteration: 7
# Weights: [ 1.         -1.86457479 -1.80014388]
# Target/Predicted function agree: True
# ======================================================================
# Run #212: successfully converged @ iteration: 20
# Weights: [ 0.          2.22223372 -3.54089075]
# Target/Predicted function agree: True
# ======================================================================
# Run #213: successfully converged @ iteration: 11
# Weights: [-1.         -2.44854576 -1.51044173]
# Target/Predicted function agree: False
# ======================================================================
# Run #214: successfully converged @ iteration: 17
# Weights: [ 1.          2.35018807 -2.74091525]
# Target/Predicted function agree: True
# ======================================================================
# Run #215: successfully converged @ iteration: 4
# Weights: [ 0.          0.28801893 -0.78490922]
# Target/Predicted function agree: True
# ======================================================================
# Run #216: successfully converged @ iteration: 0
# Weights: [0, 0, 0]
# Target/Predicted function agree: True
# ======================================================================
# Run #217: successfully converged @ iteration: 3
# Weights: [-1.         -0.67397892 -0.80058245]
# Target/Predicted function agree: True
# ======================================================================
# Run #218: successfully converged @ iteration: 1
# Weights: [-1.         -0.06486944 -0.81197309]
# Target/Predicted function agree: True
# ======================================================================
# Run #219: successfully converged @ iteration: 21
# Weights: [ 1.         -1.67862716 -2.44619469]
# Target/Predicted function agree: True
# ======================================================================
# Run #220: successfully converged @ iteration: 3
# Weights: [-1.         -1.44375819  0.38191268]
# Target/Predicted function agree: True
# ======================================================================
# Run #221: successfully converged @ iteration: 3
# Weights: [ 1.         -1.4204839  -0.25801756]
# Target/Predicted function agree: True
# ======================================================================
# Run #222: successfully converged @ iteration: 3
# Weights: [ 1.          1.85283577  0.13580518]
# Target/Predicted function agree: True
# ======================================================================
# Run #223: successfully converged @ iteration: 9
# Weights: [-1.         -1.78786967  0.78445442]
# Target/Predicted function agree: False
# ======================================================================
# Run #224: successfully converged @ iteration: 6
# Weights: [ 0.         -1.70890943 -0.98114091]
# Target/Predicted function agree: True
# ======================================================================
# Run #225: successfully converged @ iteration: 23
# Weights: [-1.         -3.38262504 -1.27720546]
# Target/Predicted function agree: True
# ======================================================================
# Run #226: successfully converged @ iteration: 7
# Weights: [-1.         -1.1400907  -2.80683959]
# Target/Predicted function agree: True
# ======================================================================
# Run #227: successfully converged @ iteration: 6
# Weights: [ 0.          0.53919528 -2.65419135]
# Target/Predicted function agree: True
# ======================================================================
# Run #228: successfully converged @ iteration: 9
# Weights: [-1.          1.66574845 -1.29709012]
# Target/Predicted function agree: True
# ======================================================================
# Run #229: successfully converged @ iteration: 2
# Weights: [ 0.         -1.8090944   0.12534934]
# Target/Predicted function agree: True
# ======================================================================
# Run #230: successfully converged @ iteration: 7
# Weights: [ 1.          2.66251568 -0.87732901]
# Target/Predicted function agree: True
# ======================================================================
# Run #231: successfully converged @ iteration: 6
# Weights: [ 0.         -0.62351253 -0.69958223]
# Target/Predicted function agree: True
# ======================================================================
# Run #232: successfully converged @ iteration: 2
# Weights: [ 0.          1.35631392 -1.39446798]
# Target/Predicted function agree: True
# ======================================================================
# Run #233: successfully converged @ iteration: 9
# Weights: [-1.         -1.34306558 -1.29521615]
# Target/Predicted function agree: True
# ======================================================================
# Run #234: successfully converged @ iteration: 2
# Weights: [ 0.          0.54077772 -0.8897279 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #235: successfully converged @ iteration: 8
# Weights: [ 0.          2.11259425 -1.90135152]
# Target/Predicted function agree: True
# ======================================================================
# Run #236: successfully converged @ iteration: 6
# Weights: [ 0.         -1.66874761 -1.19015099]
# Target/Predicted function agree: True
# ======================================================================
# Run #237: successfully converged @ iteration: 2
# Weights: [ 0.          0.78607746 -0.97495425]
# Target/Predicted function agree: True
# ======================================================================
# Run #238: successfully converged @ iteration: 2
# Weights: [ 0.         -0.43621257 -0.58780817]
# ...
# Target/Predicted function agree: True
# ======================================================================
# Run #924: successfully converged @ iteration: 2
# Weights: [ 0.          0.27160686 -1.4970615 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #925: successfully converged @ iteration: 101
# Weights: [-1.         -2.95798192 -5.5484102 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #926: successfully converged @ iteration: 21
# Weights: [ 1.         -3.6767751  -0.83508035]
# Target/Predicted function agree: True
# ======================================================================
# Run #927: successfully converged @ iteration: 7
# Weights: [-1.         -2.08416758 -0.46620202]
# Target/Predicted function agree: True
# ======================================================================
# Run #928: successfully converged @ iteration: 2
# Weights: [ 0.         -0.24991287 -1.65067206]
# Target/Predicted function agree: True
# ======================================================================
# Run #929: successfully converged @ iteration: 10
# Weights: [-2.          0.7977108  -1.75456764]
# Target/Predicted function agree: True
# ======================================================================
# Run #930: successfully converged @ iteration: 9
# Weights: [-1.          1.92561139 -1.15166258]
# Target/Predicted function agree: True
# ======================================================================
# Run #931: successfully converged @ iteration: 16
# Weights: [ 2.          2.07329091 -1.16369247]
# Target/Predicted function agree: True
# ======================================================================
# Run #932: successfully converged @ iteration: 7
# Weights: [ 1.          2.55819164  0.51384355]
# Target/Predicted function agree: True
# ======================================================================
# Run #933: successfully converged @ iteration: 3
# Weights: [-1.         -1.62307043 -0.38705249]
# Target/Predicted function agree: True
# ======================================================================
# Run #934: successfully converged @ iteration: 18
# Weights: [-2.          0.85305109 -2.11724152]
# Target/Predicted function agree: True
# ======================================================================
# Run #935: successfully converged @ iteration: 8
# Weights: [ 0.         -2.14912134 -1.65932392]
# Target/Predicted function agree: True
# ======================================================================
# Run #936: successfully converged @ iteration: 6
# Weights: [ 0.         -0.61953717 -2.11358663]
# Target/Predicted function agree: True
# ======================================================================
# Run #937: successfully converged @ iteration: 2
# Weights: [ 0.         -0.97087851 -1.48846631]
# Target/Predicted function agree: True
# ======================================================================
# Run #938: successfully converged @ iteration: 39
# Weights: [-1.         -3.640205   -2.78289867]
# Target/Predicted function agree: True
# ======================================================================
# Run #939: successfully converged @ iteration: 2
# Weights: [ 0.          0.83803845 -0.4914959 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #940: successfully converged @ iteration: 3
# Weights: [-1.          1.71088215 -0.22945322]
# Target/Predicted function agree: True
# ======================================================================
# Run #941: successfully converged @ iteration: 8
# Weights: [ 2.         -1.50447103 -1.2455918 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #942: successfully converged @ iteration: 3
# Weights: [-1.          1.84072711 -0.29162437]
# Target/Predicted function agree: True
# ======================================================================
# Run #943: successfully converged @ iteration: 12
# Weights: [ 0.          3.77296665 -0.64022349]
# Target/Predicted function agree: True
# ======================================================================
# Run #944: successfully converged @ iteration: 13
# Weights: [ 1.          2.0443171  -1.66240473]
# Target/Predicted function agree: True
# ======================================================================
# Run #945: successfully converged @ iteration: 5
# Weights: [-1.         -0.96933108 -0.76000543]
# Target/Predicted function agree: True
# ======================================================================
# Run #946: successfully converged @ iteration: 4
# Weights: [ 0.         -0.69585374 -2.0047741 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #947: successfully converged @ iteration: 7
# Weights: [-1.          0.63548407 -1.52610195]
# Target/Predicted function agree: True
# ======================================================================
# Run #948: successfully converged @ iteration: 17
# Weights: [ 1.          2.35879342 -2.30654835]
# Target/Predicted function agree: True
# ======================================================================
# Run #949: successfully converged @ iteration: 1
# Weights: [-1.         -0.20556562 -0.67075068]
# Target/Predicted function agree: True
# ======================================================================
# Run #950: successfully converged @ iteration: 7
# Weights: [-1.          0.22067238 -1.99079311]
# Target/Predicted function agree: False
# ======================================================================
# Run #951: successfully converged @ iteration: 28
# Weights: [-2.         -2.69511149 -2.32708663]
# Target/Predicted function agree: True
# ======================================================================
# Run #952: successfully converged @ iteration: 3
# Weights: [ 1.         -0.63476787 -0.72808518]
# Target/Predicted function agree: True
# ======================================================================
# Run #953: successfully converged @ iteration: 12
# Weights: [ 0.          2.0275737  -1.38419204]
# Target/Predicted function agree: True
# ======================================================================
# Run #954: successfully converged @ iteration: 5
# Weights: [ 1.         -1.60090102 -0.82356249]
# Target/Predicted function agree: True
# ======================================================================
# Run #955: successfully converged @ iteration: 7
# Weights: [-1.         -1.36435811  1.25619763]
# Target/Predicted function agree: True
# ======================================================================
# Run #956: successfully converged @ iteration: 2
# Weights: [ 0.         -1.13883474 -0.17991721]
# Target/Predicted function agree: True
# ======================================================================
# Run #957: successfully converged @ iteration: 10
# Weights: [ 0.         -1.8450391  -0.48289441]
# Target/Predicted function agree: True
# ======================================================================
# Run #958: successfully converged @ iteration: 9
# Weights: [ 1.         -2.77193704 -1.05656034]
# Target/Predicted function agree: True
# ======================================================================
# Run #959: successfully converged @ iteration: 5
# Weights: [-1.         -1.59543546 -0.65566688]
# Target/Predicted function agree: True
# ======================================================================
# Run #960: successfully converged @ iteration: 11
# Weights: [-1.        -0.5025803 -2.374259 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #961: successfully converged @ iteration: 1
# Weights: [-1.         -0.12380492 -0.23650525]
# Target/Predicted function agree: True
# ======================================================================
# Run #962: successfully converged @ iteration: 13
# Weights: [ 1.          2.02393531 -0.47096597]
# Target/Predicted function agree: True
# ======================================================================
# Run #963: successfully converged @ iteration: 6
# Weights: [ 0.         -1.62057565 -0.97973444]
# Target/Predicted function agree: True
# ======================================================================
# Run #964: successfully converged @ iteration: 1
# Weights: [-1.         -0.48643481  0.74658298]
# Target/Predicted function agree: False
# ======================================================================
# Run #965: successfully converged @ iteration: 2
# Weights: [ 0.         -1.00484605 -0.9384369 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #966: successfully converged @ iteration: 1
# Weights: [-1.         -0.89482292  0.10106248]
# Target/Predicted function agree: True
# ======================================================================
# Run #967: successfully converged @ iteration: 16
# Weights: [-2.         -0.05265797 -2.21277245]
# Target/Predicted function agree: True
# ======================================================================
# Run #968: successfully converged @ iteration: 1
# Weights: [-1.         -0.20710867 -0.63440302]
# Target/Predicted function agree: True
# ======================================================================
# Run #969: successfully converged @ iteration: 7
# Weights: [-1.          2.59705892  0.26171792]
# Target/Predicted function agree: True
# ======================================================================
# Run #970: successfully converged @ iteration: 7
# Weights: [-1.         -1.50031638 -0.76310733]
# Target/Predicted function agree: True
# ======================================================================
# Run #971: successfully converged @ iteration: 8
# Weights: [ 0.         -0.49081556 -1.8717997 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #972: successfully converged @ iteration: 9
# Weights: [-1.         -0.6014044  -2.21976376]
# Target/Predicted function agree: True
# ======================================================================
# Run #973: successfully converged @ iteration: 3
# Weights: [ 1.         -0.57665384 -1.05742627]
# Target/Predicted function agree: True
# ======================================================================
# Run #974: successfully converged @ iteration: 8
# Weights: [ 0.         -1.20365224 -1.92115226]
# Target/Predicted function agree: True
# ======================================================================
# Run #975: successfully converged @ iteration: 17
# Weights: [-1.          1.62646516 -2.84872449]
# Target/Predicted function agree: True
# ======================================================================
# Run #976: successfully converged @ iteration: 8
# Weights: [ 0.          2.31181258 -1.73355537]
# Target/Predicted function agree: True
# ======================================================================
# Run #977: successfully converged @ iteration: 5
# Weights: [-1.         -0.24067752 -2.33229924]
# Target/Predicted function agree: True
# ======================================================================
# Run #978: successfully converged @ iteration: 14
# Weights: [ 0.          2.61814567 -2.02297494]
# Target/Predicted function agree: True
# ======================================================================
# Run #979: successfully converged @ iteration: 3
# Weights: [ 1.          1.24312791 -0.85963545]
# Target/Predicted function agree: True
# ======================================================================
# Run #980: successfully converged @ iteration: 2
# Weights: [ 0.          0.7470541  -0.54582996]
# Target/Predicted function agree: True
# ======================================================================
# Run #981: successfully converged @ iteration: 9
# Weights: [-1.         -1.85944634 -0.63121682]
# Target/Predicted function agree: True
# ======================================================================
# Run #982: successfully converged @ iteration: 7
# Weights: [ 1.         -1.7081355  -0.31493336]
# Target/Predicted function agree: True
# ======================================================================
# Run #983: successfully converged @ iteration: 3
# Weights: [-1.         -0.66512933 -0.91529092]
# Target/Predicted function agree: True
# ======================================================================
# Run #984: successfully converged @ iteration: 4
# Weights: [ 0.         -1.64772971 -0.77466382]
# Target/Predicted function agree: True
# ======================================================================
# Run #985: successfully converged @ iteration: 1
# Weights: [-1.         -0.19463255 -0.22611623]
# Target/Predicted function agree: True
# ======================================================================
# Run #986: successfully converged @ iteration: 5
# Weights: [-1.         -1.60202687 -1.17679933]
# Target/Predicted function agree: True
# ======================================================================
# Run #987: successfully converged @ iteration: 2
# Weights: [ 0.          1.03763886 -1.83125608]
# Target/Predicted function agree: True
# ======================================================================
# Run #988: successfully converged @ iteration: 23
# Weights: [ 1.         -4.07032804 -2.33868926]
# Target/Predicted function agree: True
# ======================================================================
# Run #989: successfully converged @ iteration: 69
# Weights: [ 3.         -0.34000034 -4.61105344]
# Target/Predicted function agree: True
# ======================================================================
# Run #990: successfully converged @ iteration: 15
# Weights: [-1.         -3.20163381 -2.23389585]
# Target/Predicted function agree: True
# ======================================================================
# Run #991: successfully converged @ iteration: 4
# Weights: [ 0.          1.95732241  0.17686118]
# Target/Predicted function agree: True
# ======================================================================
# Run #992: successfully converged @ iteration: 4
# Weights: [ 0.          0.69232868 -1.24746377]
# Target/Predicted function agree: True
# ======================================================================
# Run #993: successfully converged @ iteration: 18
# Weights: [ 2.          0.32043043 -2.7272563 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #994: successfully converged @ iteration: 5
# Weights: [-1.         -1.70882419 -1.04909074]
# Target/Predicted function agree: True
# ======================================================================
# Run #995: successfully converged @ iteration: 48
# Weights: [ 2.         -3.19655639 -2.52540142]
# Target/Predicted function agree: True
# ======================================================================
# Run #996: successfully converged @ iteration: 7
# Weights: [ 1.         -2.46921613 -1.37172308]
# Target/Predicted function agree: True
# ======================================================================
# Run #997: successfully converged @ iteration: 12
# Weights: [ 2.          1.99985338 -1.31370812]
# Target/Predicted function agree: True
# ======================================================================
# Run #998: successfully converged @ iteration: 18
# Weights: [ 2.          0.93016929 -3.19704421]
# Target/Predicted function agree: True
# ======================================================================
# Run #999: successfully converged @ iteration: 5
# Weights: [-1.          1.01445062 -1.5465229 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #1000: successfully converged @ iteration: 4
# Weights: [ 0.          0.8896137  -1.45768796]
# Target/Predicted function agree: True
# ======================================================================
# Avg. iteration to succussfully converged: 9
# Probabily that f and g will disagree on their classfication of a random point: 0.0990

# %%
Simple_PLA(N = 100)
# Out:
# Run #1: successfully converged @ iteration: 609
# Weights: [ -7.         -14.66053979  -7.42301055]
# Target/Predicted function agree: True
# ======================================================================
# Run #2: successfully converged @ iteration: 105
# Weights: [ 3.         -3.54347295 -6.78132946]
# Target/Predicted function agree: True
# ======================================================================
# Run #3: successfully converged @ iteration: 63
# Weights: [ 3.          5.46159014 -4.53085709]
# Target/Predicted function agree: True
# ======================================================================
# Run #4: successfully converged @ iteration: 54
# Weights: [ 4.         -5.53902618 -0.89440389]
# Target/Predicted function agree: True
# ======================================================================
# Run #5: successfully converged @ iteration: 17
# Weights: [-1.          0.67422944 -4.07765881]
# Target/Predicted function agree: True
# ======================================================================
# Run #6: successfully converged @ iteration: 16
# Weights: [ 2.          2.85969123 -1.21255643]
# Target/Predicted function agree: True
# ======================================================================
# Run #7: successfully converged @ iteration: 41
# Weights: [-1.          0.64828412 -5.18096687]
# Target/Predicted function agree: True
# ======================================================================
# Run #8: successfully converged @ iteration: 123
# Weights: [-5.         -8.23429693 -2.37020891]
# Target/Predicted function agree: True
# ======================================================================
# Run #9: successfully converged @ iteration: 63
# Weights: [ 3.         -1.1874486  -6.01564174]
# Target/Predicted function agree: True
# ======================================================================
# Run #10: successfully converged @ iteration: 40
# Weights: [ 0.          5.72937889 -2.61857953]
# Target/Predicted function agree: True
# ======================================================================
# Run #11: successfully converged @ iteration: 152
# Weights: [ 4.          7.94463514 -5.35024915]
# Target/Predicted function agree: True
# ======================================================================
# Run #12: successfully converged @ iteration: 76
# Weights: [ 2.         -5.67718831 -4.21073495]
# Target/Predicted function agree: True
# ======================================================================
# Run #13: successfully converged @ iteration: 69
# Weights: [-1.         -6.62513319 -3.50758552]
# Target/Predicted function agree: True
# ======================================================================
# Run #14: successfully converged @ iteration: 13
# Weights: [ 1.          0.60483034 -3.24102479]
# Target/Predicted function agree: True
# ======================================================================
# Run #15: successfully converged @ iteration: 37
# Weights: [ 3.         -3.18701794 -2.05495969]
# Target/Predicted function agree: True
# ======================================================================
# Run #16: successfully converged @ iteration: 73
# Weights: [ 3.         -5.76465926 -2.58634241]
# Target/Predicted function agree: True
# ======================================================================
# Run #17: successfully converged @ iteration: 231
# Weights: [ -1.           3.5609659  -11.95035939]
# Target/Predicted function agree: True
# ======================================================================
# Run #18: successfully converged @ iteration: 16
# Weights: [-2.         -0.95709965 -2.98613736]
# Target/Predicted function agree: True
# ======================================================================
# Run #19: successfully converged @ iteration: 18
# Weights: [-2.          2.85907669 -1.63321505]
# Target/Predicted function agree: True
# ======================================================================
# Run #20: successfully converged @ iteration: 106
# Weights: [-2.         -2.71495754 -8.96062957]
# Target/Predicted function agree: True
# ======================================================================
# Run #21: successfully converged @ iteration: 36
# Weights: [-2.         -1.56822643 -4.08508233]
# Target/Predicted function agree: True
# ======================================================================
# Run #22: successfully converged @ iteration: 27
# Weights: [ 3.         -2.7063024  -2.94398693]
# Target/Predicted function agree: True
# ======================================================================
# Run #23: successfully converged @ iteration: 74
# Weights: [-2.         -7.05414314 -2.7688897 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #24: successfully converged @ iteration: 155
# Weights: [ 1.          5.25255908 -8.96083995]
# Target/Predicted function agree: True
# ======================================================================
# Run #25: successfully converged @ iteration: 15
# Weights: [-1.         -1.18730439 -3.09509278]
# Target/Predicted function agree: True
# ======================================================================
# Run #26: successfully converged @ iteration: 18
# Weights: [ 2.          1.39622604 -3.29526701]
# Target/Predicted function agree: True
# ======================================================================
# Run #27: successfully converged @ iteration: 44
# Weights: [-2.          5.31619422 -1.99649246]
# Target/Predicted function agree: True
# ======================================================================
# Run #28: successfully converged @ iteration: 151
# Weights: [-3.         -8.12700497 -6.29005167]
# Target/Predicted function agree: True
# ======================================================================
# Run #29: successfully converged @ iteration: 30
# Weights: [ 2.         -0.34849545 -4.66687827]
# Target/Predicted function agree: True
# ======================================================================
# Run #30: successfully converged @ iteration: 22
# Weights: [-2.          1.42274324 -3.44045962]
# Target/Predicted function agree: True
# ======================================================================
# Run #31: successfully converged @ iteration: 51
# Weights: [-3.          4.43867546 -2.64010734]
# Target/Predicted function agree: True
# ======================================================================
# Run #32: successfully converged @ iteration: 20
# Weights: [ 0.          0.48912245 -3.93712429]
# Target/Predicted function agree: True
# ======================================================================
# Run #33: successfully converged @ iteration: 48
# Weights: [-2.         -3.96493183 -4.17836915]
# Target/Predicted function agree: True
# ======================================================================
# Run #34: successfully converged @ iteration: 116
# Weights: [ 6.         -1.88939116 -7.6726217 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #35: successfully converged @ iteration: 21
# Weights: [-1.         -1.65125846 -2.78820221]
# Target/Predicted function agree: True
# ======================================================================
# Run #36: successfully converged @ iteration: 36
# Weights: [ 2.          2.61990731 -4.97198389]
# Target/Predicted function agree: True
# ======================================================================
# Run #37: successfully converged @ iteration: 333
# Weights: [ 11.          -0.39678181 -11.66420455]
# Target/Predicted function agree: True
# ======================================================================
# Run #38: successfully converged @ iteration: 90
# Weights: [-4.          3.24368119 -6.95236733]
# Target/Predicted function agree: True
# ======================================================================
# Run #39: successfully converged @ iteration: 33
# Weights: [ 1.          4.80926028 -1.28926601]
# Target/Predicted function agree: True
# ======================================================================
# Run #40: successfully converged @ iteration: 27
# Weights: [-1.          3.76715798 -1.59353353]
# Target/Predicted function agree: True
# ======================================================================
# Run #41: successfully converged @ iteration: 93
# Weights: [ 1.         -0.05314054 -8.20406651]
# Target/Predicted function agree: True
# ======================================================================
# Run #42: successfully converged @ iteration: 91
# Weights: [-5.          7.21162812 -0.69568753]
# Target/Predicted function agree: True
# ======================================================================
# Run #43: successfully converged @ iteration: 33
# Weights: [ 3.         -2.79137509 -3.09319695]
# Target/Predicted function agree: True
# ======================================================================
# Run #44: successfully converged @ iteration: 51
# Weights: [-3.         -0.37768624 -5.65254092]
# Target/Predicted function agree: True
# ======================================================================
# Run #45: successfully converged @ iteration: 8
# Weights: [ 0.          1.35211063 -2.04903501]
# Target/Predicted function agree: True
# ======================================================================
# Run #46: successfully converged @ iteration: 97
# Weights: [ 3.         -7.3231033  -4.84291917]
# Target/Predicted function agree: True
# ======================================================================
# Run #47: successfully converged @ iteration: 59
# Weights: [ 3.         -5.51871207 -0.83003272]
# Target/Predicted function agree: True
# ======================================================================
# Run #48: successfully converged @ iteration: 14
# Weights: [ 2.          2.82757744 -0.0935089 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #49: successfully converged @ iteration: 232
# Weights: [  0.           7.75127178 -11.08322853]
# Target/Predicted function agree: True
# ======================================================================
# Run #50: successfully converged @ iteration: 76
# Weights: [ 2.         -4.80534661 -4.2755067 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #51: successfully converged @ iteration: 12
# Weights: [-2.          2.54808076 -0.28239732]
# Target/Predicted function agree: True
# ======================================================================
# Run #52: successfully converged @ iteration: 62
# Weights: [-4.         -1.69968779 -5.44463045]
# Target/Predicted function agree: True
# ======================================================================
# Run #53: successfully converged @ iteration: 156
# Weights: [ 2.          9.94469402 -1.3938165 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #54: successfully converged @ iteration: 62
# Weights: [-4.         -4.47939974 -2.93539984]
# Target/Predicted function agree: True
# ======================================================================
# Run #55: successfully converged @ iteration: 117
# Weights: [ 1.         -4.97472167 -8.69392836]
# Target/Predicted function agree: True
# ======================================================================
# Run #56: successfully converged @ iteration: 49
# Weights: [-3.         -4.76717026 -2.87235525]
# Target/Predicted function agree: True
# ======================================================================
# Run #57: successfully converged @ iteration: 15
# Weights: [-1.         -3.45370084 -1.09697764]
# Target/Predicted function agree: True
# ======================================================================
# Run #58: successfully converged @ iteration: 19
# Weights: [ 1.          0.81143333 -2.77755935]
# Target/Predicted function agree: True
# ======================================================================
# Run #59: successfully converged @ iteration: 111
# Weights: [-3.          0.43304406 -8.21250018]
# Target/Predicted function agree: True
# ======================================================================
# Run #60: successfully converged @ iteration: 82
# Weights: [ 0.         -5.86709522 -4.71816699]
# Target/Predicted function agree: True
# ======================================================================
# Run #61: successfully converged @ iteration: 165
# Weights: [-7.          1.85643918 -9.27485952]
# Target/Predicted function agree: True
# ======================================================================
# Run #62: successfully converged @ iteration: 70
# Weights: [-2.          5.63680357 -3.81476466]
# Target/Predicted function agree: True
# ======================================================================
# Run #63: successfully converged @ iteration: 11
# Weights: [-1.          0.12589968 -3.08031428]
# Target/Predicted function agree: True
# ======================================================================
# Run #64: successfully converged @ iteration: 80
# Weights: [ 0.         -6.67831438 -4.83740934]
# Target/Predicted function agree: True
# ======================================================================
# Run #65: successfully converged @ iteration: 47
# Weights: [-1.          1.93548099 -5.24824401]
# Target/Predicted function agree: True
# ======================================================================
# Run #66: successfully converged @ iteration: 159
# Weights: [-3.         -8.58490606 -7.37136299]
# Target/Predicted function agree: True
# ======================================================================
# Run #67: successfully converged @ iteration: 49
# Weights: [ 1.          2.4019981  -5.31806657]
# Target/Predicted function agree: True
# ======================================================================
# Run #68: successfully converged @ iteration: 37
# Weights: [-1.         -2.81833951 -4.2120898 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #69: successfully converged @ iteration: 52
# Weights: [-4.          1.68601072 -4.77490391]
# Target/Predicted function agree: True
# ======================================================================
# Run #70: successfully converged @ iteration: 38
# Weights: [-2.         -1.83758215 -4.80774183]
# Target/Predicted function agree: True
# ======================================================================
# Run #71: successfully converged @ iteration: 27
# Weights: [ 3.          2.35467141 -3.27775326]
# Target/Predicted function agree: True
# ======================================================================
# Run #72: successfully converged @ iteration: 49
# Weights: [ 3.         -5.8065564  -1.92916149]
# Target/Predicted function agree: True
# ======================================================================
# Run #73: successfully converged @ iteration: 37
# Weights: [ 3.          4.17273749 -1.15896425]
# Target/Predicted function agree: True
# ======================================================================
# Run #74: successfully converged @ iteration: 11
# Weights: [-1.          1.78058888 -2.05344629]
# Target/Predicted function agree: True
# ======================================================================
# Run #75: successfully converged @ iteration: 141
# Weights: [-1.         -6.65622997 -8.31215334]
# Target/Predicted function agree: True
# ======================================================================
# Run #76: successfully converged @ iteration: 181
# Weights: [  5.           0.34531537 -10.79084539]
# Target/Predicted function agree: True
# ======================================================================
# Run #77: successfully converged @ iteration: 93
# Weights: [-3.         -4.50845397 -7.35550356]
# Target/Predicted function agree: True
# ======================================================================
# Run #78: successfully converged @ iteration: 93
# Weights: [ 1.          1.97839532 -8.0500326 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #79: successfully converged @ iteration: 127
# Weights: [-1.         -8.40689224 -6.69620223]
# Target/Predicted function agree: True
# ======================================================================
# Run #80: successfully converged @ iteration: 100
# Weights: [-2.          4.52180486 -7.0753486 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #81: successfully converged @ iteration: 385
# Weights: [  1.00000000e+00  -3.56066739e-03  -1.45255336e+01]
# Target/Predicted function agree: True
# ======================================================================
# Run #82: successfully converged @ iteration: 54
# Weights: [ 2.         -6.04895323 -2.27554642]
# Target/Predicted function agree: True
# ======================================================================
# Run #83: successfully converged @ iteration: 912
# Weights: [  8.          11.50214468 -11.94258464]
# Target/Predicted function agree: True
# ======================================================================
# Run #84: successfully converged @ iteration: 169
# Weights: [ 3.          9.59054085 -6.7289769 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #85: successfully converged @ iteration: 85
# Weights: [ 3.         -2.54735571 -6.09813307]
# Target/Predicted function agree: True
# ======================================================================
# Run #86: successfully converged @ iteration: 41
# Weights: [-3.          4.15739759 -1.76294869]
# Target/Predicted function agree: True
# ======================================================================
# Run #87: successfully converged @ iteration: 65
# Weights: [-3.          6.04936673 -1.5228513 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #88: successfully converged @ iteration: 20
# Weights: [ 2.          2.8641606  -2.07054657]
# Target/Predicted function agree: True
# ======================================================================
# Run #89: successfully converged @ iteration: 41
# Weights: [-1.          5.41397078 -0.89414732]
# Target/Predicted function agree: True
# ======================================================================
# Run #90: successfully converged @ iteration: 17
# Weights: [-1.          1.33365219 -3.70153171]
# Target/Predicted function agree: True
# ======================================================================
# Run #91: successfully converged @ iteration: 22
# Weights: [ 2.          3.87468912 -0.49301853]
# Target/Predicted function agree: True
# ======================================================================
# Run #92: successfully converged @ iteration: 47
# Weights: [-3.          3.6605954  -4.53598808]
# Target/Predicted function agree: True
# ======================================================================
# Run #93: successfully converged @ iteration: 17
# Weights: [-3.          1.3282518  -2.19188707]
# Target/Predicted function agree: True
# ======================================================================
# Run #94: successfully converged @ iteration: 43
# Weights: [ 3.          4.59415364 -2.1309653 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #95: successfully converged @ iteration: 120
# Weights: [ 2.         -7.03809006 -5.85356591]
# Target/Predicted function agree: True
# ======================================================================
# Run #96: successfully converged @ iteration: 121
# Weights: [ 3.          7.57565386 -3.91953662]
# Target/Predicted function agree: True
# ======================================================================
# Run #97: successfully converged @ iteration: 157
# Weights: [ 1.          7.71495441 -8.05828133]
# Target/Predicted function agree: True
# ======================================================================
# Run #98: successfully converged @ iteration: 32
# Weights: [ 0.         -1.89225727 -5.09118832]
# Target/Predicted function agree: True
# ======================================================================
# Run #99: successfully converged @ iteration: 127
# Weights: [-5.         -7.97893552 -1.47280118]
# Target/Predicted function agree: True
# ======================================================================
# Run #100: successfully converged @ iteration: 92
# Weights: [ 2.         -5.79429932 -6.67749693]
# Target/Predicted function agree: True
# ======================================================================
# Run #101: successfully converged @ iteration: 109
# Weights: [-5.          7.17245576 -3.14132672]
# Target/Predicted function agree: True
# ======================================================================
# Run #102: successfully converged @ iteration: 77
# Weights: [ 1.          6.59783635 -1.94694296]
# Target/Predicted function agree: True
# ======================================================================
# Run #103: successfully converged @ iteration: 256
# Weights: [ -6.         5.23592  -12.730696]
# Target/Predicted function agree: True
# ======================================================================
# Run #104: successfully converged @ iteration: 172
# Weights: [ 4.         7.0930928 -8.0305014]
# Target/Predicted function agree: True
# ======================================================================
# Run #105: successfully converged @ iteration: 7
# Weights: [-1.         -1.75930246 -0.4256296 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #106: successfully converged @ iteration: 82
# Weights: [-2.          0.02047387 -7.90786935]
# Target/Predicted function agree: True
# ======================================================================
# Run #107: successfully converged @ iteration: 37
# Weights: [-1.         -2.51656681 -4.3751437 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #108: successfully converged @ iteration: 2
# Weights: [ 0.          1.54533295 -0.98592719]
# Target/Predicted function agree: True
# ======================================================================
# Run #109: successfully converged @ iteration: 19
# Weights: [ 1.          0.12863039 -3.6222672 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #110: successfully converged @ iteration: 11
# Weights: [-1.          2.69875323 -0.68394513]
# Target/Predicted function agree: True
# ======================================================================
# Run #111: successfully converged @ iteration: 45
# Weights: [-1.         -5.33017981 -1.58935786]
# Target/Predicted function agree: True
# ======================================================================
# Run #112: successfully converged @ iteration: 156
# Weights: [ 4.         -5.81253506 -8.60103333]
# Target/Predicted function agree: True
# ======================================================================
# Run #113: successfully converged @ iteration: 15
# Weights: [-3.         -1.72767649 -2.57205975]
# Target/Predicted function agree: True
# ======================================================================
# Run #114: successfully converged @ iteration: 52
# Weights: [-4.         -0.18353119 -5.3268511 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #115: successfully converged @ iteration: 127
# Weights: [ 7.         -5.84780631 -2.55058041]
# Target/Predicted function agree: True
# ======================================================================
# Run #116: successfully converged @ iteration: 164
# Weights: [ 4.          8.76749754 -5.78214756]
# Target/Predicted function agree: True
# ======================================================================
# Run #117: successfully converged @ iteration: 51
# Weights: [ 3.         -0.97178546 -5.56490999]
# Target/Predicted function agree: True
# ======================================================================
# Run #118: successfully converged @ iteration: 331
# Weights: [ -7.          3.7417473 -13.4007515]
# Target/Predicted function agree: True
# ======================================================================
# Run #119: successfully converged @ iteration: 129
# Weights: [-1.         -8.52700495 -3.55643299]
# Target/Predicted function agree: True
# ======================================================================
# Run #120: successfully converged @ iteration: 51
# Weights: [-1.          5.01719704 -3.13471165]
# Target/Predicted function agree: True
# ======================================================================
# Run #121: successfully converged @ iteration: 104
# Weights: [-2.         -8.12104101 -4.54364369]
# Target/Predicted function agree: True
# ======================================================================
# Run #122: successfully converged @ iteration: 29
# Weights: [ 3.          2.88010569 -2.48248352]
# Target/Predicted function agree: True
# ======================================================================
# Run #123: successfully converged @ iteration: 176
# Weights: [ 8.          0.17688782 -9.59988273]
# Target/Predicted function agree: True
# ======================================================================
# Run #124: successfully converged @ iteration: 115
# Weights: [-3.          5.56886691 -5.25387972]
# Target/Predicted function agree: True
# ======================================================================
# Run #125: successfully converged @ iteration: 12
# Weights: [ 0.         -0.41674194 -3.17619735]
# Target/Predicted function agree: True
# ======================================================================
# Run #126: successfully converged @ iteration: 15
# Weights: [ 1.          2.90667905 -1.41653388]
# Target/Predicted function agree: True
# ======================================================================
# Run #127: successfully converged @ iteration: 100
# Weights: [ 4.          3.18942318 -8.24837206]
# Target/Predicted function agree: True
# ======================================================================
# Run #128: successfully converged @ iteration: 142
# Weights: [ 6.         7.1534459 -2.5786137]
# Target/Predicted function agree: True
# ======================================================================
# Run #129: successfully converged @ iteration: 14
# Weights: [ 2.          0.7560131  -2.68804384]
# Target/Predicted function agree: True
# ======================================================================
# Run #130: successfully converged @ iteration: 33
# Weights: [-3.          3.74619465 -0.6308325 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #131: successfully converged @ iteration: 18
# Weights: [-2.          3.21231825 -1.71326194]
# Target/Predicted function agree: True
# ======================================================================
# Run #132: successfully converged @ iteration: 229
# Weights: [  1.          11.86269686  -0.3607571 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #133: successfully converged @ iteration: 146
# Weights: [-6.         -7.33684208 -0.28920679]
# Target/Predicted function agree: True
# ======================================================================
# Run #134: successfully converged @ iteration: 50
# Weights: [ 0.          4.34301054 -4.12318265]
# Target/Predicted function agree: True
# ======================================================================
# Run #135: successfully converged @ iteration: 7
# Weights: [ 1.          1.00191014 -0.57577185]
# Target/Predicted function agree: True
# ======================================================================
# Run #136: successfully converged @ iteration: 59
# Weights: [ 1.         -2.8736715  -6.05232305]
# Target/Predicted function agree: True
# ======================================================================
# Run #137: successfully converged @ iteration: 71
# Weights: [-3.         -5.30806696 -3.88214351]
# Target/Predicted function agree: True
# ======================================================================
# Run #138: successfully converged @ iteration: 15
# Weights: [-1.          2.31058163 -1.65512955]
# Target/Predicted function agree: True
# ======================================================================
# Run #139: successfully converged @ iteration: 267
# Weights: [  9.         -10.40056637  -3.69548946]
# Target/Predicted function agree: True
# ======================================================================
# Run #140: successfully converged @ iteration: 29
# Weights: [ 1.          2.36476411 -4.89935902]
# Target/Predicted function agree: True
# ======================================================================
# Run #141: successfully converged @ iteration: 65
# Weights: [-1.          6.54687267  0.02549943]
# Target/Predicted function agree: True
# ======================================================================
# Run #142: successfully converged @ iteration: 19
# Weights: [-1.         -3.16863477 -2.08013079]
# Target/Predicted function agree: True
# ======================================================================
# Run #143: successfully converged @ iteration: 10
# Weights: [-2.          2.05871135 -0.38727388]
# Target/Predicted function agree: True
# ======================================================================
# Run #144: successfully converged @ iteration: 50
# Weights: [ 2.         -6.89670905 -0.7211129 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #145: successfully converged @ iteration: 39
# Weights: [-3.          0.78347668 -4.94063773]
# Target/Predicted function agree: True
# ======================================================================
# Run #146: successfully converged @ iteration: 27
# Weights: [ 1.         -4.98598842 -1.10948164]
# Target/Predicted function agree: False
# ======================================================================
# Run #147: successfully converged @ iteration: 24
# Weights: [ 2.         -3.17738269 -2.29132376]
# Target/Predicted function agree: True
# ======================================================================
# Run #148: successfully converged @ iteration: 16
# Weights: [ 2.          3.12043238 -0.1473545 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #149: successfully converged @ iteration: 64
# Weights: [ 0.          5.97820512 -5.32991566]
# Target/Predicted function agree: True
# ======================================================================
# Run #150: successfully converged @ iteration: 56
# Weights: [ 2.          6.49091442 -0.64404883]
# Target/Predicted function agree: True
# ======================================================================
# Run #151: successfully converged @ iteration: 51
# Weights: [-1.          5.22684716 -4.43130738]
# Target/Predicted function agree: True
# ======================================================================
# Run #152: successfully converged @ iteration: 119
# Weights: [ 1.         -8.39612211 -2.5930761 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #153: successfully converged @ iteration: 37
# Weights: [ 3.          2.81185995 -3.21507105]
# Target/Predicted function agree: True
# ======================================================================
# Run #154: successfully converged @ iteration: 41
# Weights: [ 3.          0.96837877 -5.01291916]
# Target/Predicted function agree: True
# ======================================================================
# Run #155: successfully converged @ iteration: 266
# Weights: [ 10.          -2.58114342 -11.54416617]
# Target/Predicted function agree: True
# ======================================================================
# Run #156: successfully converged @ iteration: 55
# Weights: [-3.         -4.54081382 -2.5918689 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #157: successfully converged @ iteration: 224
# Weights: [ 6.          4.9842036  -8.56116198]
# Target/Predicted function agree: True
# ======================================================================
# Run #158: successfully converged @ iteration: 148
# Weights: [ 0.          9.86966971 -0.53495787]
# Target/Predicted function agree: True
# ======================================================================
# Run #159: successfully converged @ iteration: 127
# Weights: [ 1.          5.18439473 -9.2250425 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #160: successfully converged @ iteration: 72
# Weights: [ 2.         -6.88812235 -1.28933384]
# Target/Predicted function agree: True
# ======================================================================
# Run #161: successfully converged @ iteration: 357
# Weights: [ -1.          -5.13785338 -14.83960925]
# Target/Predicted function agree: True
# ======================================================================
# Run #162: successfully converged @ iteration: 324
# Weights: [  2.         -11.73174198 -11.81002117]
# Target/Predicted function agree: True
# ======================================================================
# Run #163: successfully converged @ iteration: 61
# Weights: [ 1.         -5.63046677 -2.86579901]
# Target/Predicted function agree: True
# ======================================================================
# Run #164: successfully converged @ iteration: 319
# Weights: [  9.          -1.78187042 -10.34484286]
# Target/Predicted function agree: True
# ======================================================================
# Run #165: successfully converged @ iteration: 128
# Weights: [-4.         -2.73845949 -7.78325564]
# Target/Predicted function agree: True
# ======================================================================
# Run #166: successfully converged @ iteration: 151
# Weights: [ -1.           5.98402852 -10.01922786]
# Target/Predicted function agree: True
# ======================================================================
# Run #167: successfully converged @ iteration: 87
# Weights: [ 5.         -6.8251685  -0.98758515]
# Target/Predicted function agree: True
# ======================================================================
# Run #168: successfully converged @ iteration: 43
# Weights: [-3.          3.9329854  -0.36061747]
# Target/Predicted function agree: True
# ======================================================================
# Run #169: successfully converged @ iteration: 121
# Weights: [ 3.          8.00992042 -1.57588787]
# Target/Predicted function agree: True
# ======================================================================
# Run #170: successfully converged @ iteration: 45
# Weights: [ 1.          5.0177103  -3.09002749]
# Target/Predicted function agree: True
# ======================================================================
# Run #171: successfully converged @ iteration: 189
# Weights: [ 5.          6.05339702 -7.78500373]
# Target/Predicted function agree: True
# ======================================================================
# Run #172: successfully converged @ iteration: 11
# Weights: [-1.          2.4424781  -1.31726024]
# Target/Predicted function agree: True
# ======================================================================
# Run #173: successfully converged @ iteration: 82
# Weights: [-4.          4.72585081 -5.6599221 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #174: successfully converged @ iteration: 29
# Weights: [-1.         -0.40242392 -4.82375179]
# Target/Predicted function agree: True
# ======================================================================
# Run #175: successfully converged @ iteration: 80
# Weights: [ 2.          6.64631658 -3.29550365]
# Target/Predicted function agree: True
# ======================================================================
# Run #176: successfully converged @ iteration: 40
# Weights: [-2.         -3.45940638 -3.60648359]
# Target/Predicted function agree: True
# ======================================================================
# Run #177: successfully converged @ iteration: 133
# Weights: [-3.          2.68034054 -8.40524316]
# Target/Predicted function agree: True
# ======================================================================
# Run #178: successfully converged @ iteration: 52
# Weights: [ 4.          0.2063389  -4.78178898]
# Target/Predicted function agree: True
# ======================================================================
# Run #179: successfully converged @ iteration: 105
# Weights: [-5.          7.97232446 -1.62218633]
# Target/Predicted function agree: True
# ======================================================================
# Run #180: successfully converged @ iteration: 35
# Weights: [ 3.         -3.7088599  -0.82757345]
# Target/Predicted function agree: True
# ======================================================================
# Run #181: successfully converged @ iteration: 73
# Weights: [-5.          0.62070747 -6.65791506]
# Target/Predicted function agree: True
# ======================================================================
# Run #182: successfully converged @ iteration: 52
# Weights: [-4.          4.75924573 -0.89649674]
# Target/Predicted function agree: True
# ======================================================================
# Run #183: successfully converged @ iteration: 150
# Weights: [-4.         -5.58441754 -7.80339959]
# Target/Predicted function agree: True
# ======================================================================
# Run #184: successfully converged @ iteration: 49
# Weights: [-1.          5.19660643 -3.58401487]
# Target/Predicted function agree: True
# ======================================================================
# Run #185: successfully converged @ iteration: 39
# Weights: [-1.         -5.01694845 -2.25760243]
# Target/Predicted function agree: True
# ======================================================================
# Run #186: successfully converged @ iteration: 57
# Weights: [-1.          4.37920555 -6.01045521]
# Target/Predicted function agree: True
# ======================================================================
# Run #187: successfully converged @ iteration: 117
# Weights: [ 1.          5.44042987 -7.11840092]
# Target/Predicted function agree: True
# ======================================================================
# Run #188: successfully converged @ iteration: 40
# Weights: [ 4.          3.94493702 -1.94517922]
# Target/Predicted function agree: True
# ======================================================================
# Run #189: successfully converged @ iteration: 763
# Weights: [  1.          14.29225199 -20.36398294]
# Target/Predicted function agree: True
# ======================================================================
# Run #190: successfully converged @ iteration: 28
# Weights: [ 2.         -3.78707302 -1.18721858]
# Target/Predicted function agree: True
# ======================================================================
# Run #191: successfully converged @ iteration: 66
# Weights: [ 2.          6.50601357 -2.58679149]
# Target/Predicted function agree: True
# ======================================================================
# Run #192: successfully converged @ iteration: 41
# Weights: [-1.         -5.79479515 -0.41253608]
# Target/Predicted function agree: True
# ======================================================================
# Run #193: successfully converged @ iteration: 167
# Weights: [ 1.         -6.24021773 -9.70651104]
# Target/Predicted function agree: True
# ======================================================================
# Run #194: successfully converged @ iteration: 73
# Weights: [ 3.          4.23155026 -4.87224958]
# Target/Predicted function agree: True
# ======================================================================
# Run #195: successfully converged @ iteration: 109
# Weights: [ 5.         -6.28013139 -3.19567075]
# Target/Predicted function agree: True
# ======================================================================
# Run #196: successfully converged @ iteration: 18
# Weights: [ 2.          1.04782143 -3.14272633]
# Target/Predicted function agree: True
# ======================================================================
# Run #197: successfully converged @ iteration: 30
# Weights: [ 2.          4.33828434 -2.20664626]
# Target/Predicted function agree: True
# ======================================================================
# Run #198: successfully converged @ iteration: 94
# Weights: [ 4.          7.4570405   0.06096651]
# Target/Predicted function agree: True
# ======================================================================
# Run #199: successfully converged @ iteration: 74
# Weights: [-2.          5.51261364 -4.00208738]
# Target/Predicted function agree: True
# ======================================================================
# Run #200: successfully converged @ iteration: 55
# Weights: [-1.         -6.0046599  -2.86995036]
# Target/Predicted function agree: True
# ======================================================================
# Run #201: successfully converged @ iteration: 64
# Weights: [-4.          6.35991254 -2.69860009]
# Target/Predicted function agree: True
# ======================================================================
# Run #202: successfully converged @ iteration: 77
# Weights: [-3.          3.13193126 -5.77635898]
# Target/Predicted function agree: True
# ======================================================================
# Run #203: successfully converged @ iteration: 26
# Weights: [-2.         -2.04431722 -4.1335247 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #204: successfully converged @ iteration: 66
# Weights: [-4.          0.69172556 -5.23849603]
# Target/Predicted function agree: True
# ======================================================================
# Run #205: successfully converged @ iteration: 11
# Weights: [-1.         -2.35384656 -1.04794779]
# Target/Predicted function agree: True
# ======================================================================
# Run #206: successfully converged @ iteration: 80
# Weights: [-4.          7.20773875 -1.7723623 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #207: successfully converged @ iteration: 25
# Weights: [ 1.         -0.69721149 -4.43690974]
# Target/Predicted function agree: True
# ======================================================================
# Run #208: successfully converged @ iteration: 53
# Weights: [-1.         -5.54141694 -3.50464566]
# Target/Predicted function agree: True
# ======================================================================
# Run #209: successfully converged @ iteration: 251
# Weights: [  1.           5.79135626 -11.35213516]
# Target/Predicted function agree: True
# ======================================================================
# Run #210: successfully converged @ iteration: 321
# Weights: [  1.          15.94676417  -0.80590095]
# Target/Predicted function agree: True
# ======================================================================
# Run #211: successfully converged @ iteration: 48
# Weights: [ 4.         -5.17249398 -0.11788121]
# Target/Predicted function agree: True
# ======================================================================
# Run #212: successfully converged @ iteration: 16
# Weights: [-2.         -1.77765037 -1.9838637 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #213: successfully converged @ iteration: 223
# Weights: [  1.           3.502671   -13.16025299]
# Target/Predicted function agree: True
# ======================================================================
# Run #214: successfully converged @ iteration: 12
# Weights: [-2.         -2.90238801 -1.92502147]
# Target/Predicted function agree: True
# ======================================================================
# Run #215: successfully converged @ iteration: 8
# Weights: [ 2.         -1.3809147  -1.39739197]
# Target/Predicted function agree: True
# ======================================================================
# Run #216: successfully converged @ iteration: 6
# Weights: [-2.          2.180719   -0.83618723]
# Target/Predicted function agree: True
# ======================================================================
# Run #217: successfully converged @ iteration: 85
# Weights: [-3.          7.40073043 -2.49292841]
# Target/Predicted function agree: True
# ======================================================================
# Run #218: successfully converged @ iteration: 89
# Weights: [ 3.          0.5167377  -7.75001778]
# Target/Predicted function agree: True
# ======================================================================
# Run #219: successfully converged @ iteration: 30
# Weights: [ 2.         -2.82237797 -3.00129335]
# Target/Predicted function agree: True
# ======================================================================
# Run #220: successfully converged @ iteration: 37
# Weights: [ 3.         -0.79277463 -4.60361246]
# Target/Predicted function agree: True
# ======================================================================
# Run #221: successfully converged @ iteration: 7
# Weights: [-1.         -1.22443381 -1.30408348]
# Target/Predicted function agree: True
# ======================================================================
# Run #222: successfully converged @ iteration: 220
# Weights: [ 8.         -9.35316973 -2.35693473]
# Target/Predicted function agree: True
# ======================================================================
# Run #223: successfully converged @ iteration: 221
# Weights: [ -5.         -11.03312954  -4.17142179]
# Target/Predicted function agree: True
# ======================================================================
# Run #224: successfully converged @ iteration: 146
# Weights: [ 2.         -4.94675816 -9.74110858]
# Target/Predicted function agree: True
# ======================================================================
# Run #225: successfully converged @ iteration: 9
# Weights: [ 1.         -1.15354935 -2.3208377 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #226: successfully converged @ iteration: 202
# Weights: [-6.          5.03703024 -7.3104775 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #227: successfully converged @ iteration: 18
# Weights: [ 0.          3.56976219 -2.01885813]
# Target/Predicted function agree: True
# ======================================================================
# Run #228: successfully converged @ iteration: 33
# Weights: [ 3.          4.23071964 -0.55754089]
# Target/Predicted function agree: True
# ======================================================================
# Run #229: successfully converged @ iteration: 133
# Weights: [-1.          7.41802853 -7.47576818]
# Target/Predicted function agree: True
# ======================================================================
# Run #230: successfully converged @ iteration: 69
# Weights: [-1.         -6.47780096 -1.44415742]
# Target/Predicted function agree: True
# ======================================================================
# Run #231: successfully converged @ iteration: 1615
# Weights: [  1.         -28.61510382 -14.0983586 ]
# Target/Predicted function agree: False
# ======================================================================
# Run #232: successfully converged @ iteration: 27
# Weights: [ 3.          2.62198105 -2.5456779 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #233: successfully converged @ iteration: 126
# Weights: [ 2.          1.07592593 -7.90007207]
# Target/Predicted function agree: True
# ======================================================================
# Run #234: successfully converged @ iteration: 20
# Weights: [-2.          2.00856046 -2.60225768]
# Target/Predicted function agree: True
# ======================================================================
# ...
# Run #924: successfully converged @ iteration: 5
# Weights: [ 1.          0.80930143 -1.43361269]
# Target/Predicted function agree: True
# ======================================================================
# Run #925: successfully converged @ iteration: 63
# Weights: [ 5.         -6.16763162 -1.01199939]
# Target/Predicted function agree: True
# ======================================================================
# Run #926: successfully converged @ iteration: 117
# Weights: [ -1.          10.45533183  -1.32746153]
# Target/Predicted function agree: True
# ======================================================================
# Run #927: successfully converged @ iteration: 53
# Weights: [-3.         -1.64600196 -5.60175983]
# Target/Predicted function agree: True
# ======================================================================
# Run #928: successfully converged @ iteration: 30
# Weights: [-2.         -3.9815873  -1.54908235]
# Target/Predicted function agree: True
# ======================================================================
# Run #929: successfully converged @ iteration: 81
# Weights: [ 1.         -1.70542808 -7.23345802]
# Target/Predicted function agree: True
# ======================================================================
# Run #930: successfully converged @ iteration: 86
# Weights: [-2.          4.40223314 -7.19423705]
# Target/Predicted function agree: True
# ======================================================================
# Run #931: successfully converged @ iteration: 43
# Weights: [-3.         -5.11213532 -0.49005563]
# Target/Predicted function agree: True
# ======================================================================
# Run #932: successfully converged @ iteration: 33
# Weights: [-3.         -3.98642901 -0.85103704]
# Target/Predicted function agree: True
# ======================================================================
# Run #933: successfully converged @ iteration: 75
# Weights: [ 5.          6.64245025 -1.90553932]
# Target/Predicted function agree: True
# ======================================================================
# Run #934: successfully converged @ iteration: 39
# Weights: [ 1.          2.83915981 -5.53797722]
# Target/Predicted function agree: True
# ======================================================================
# Run #935: successfully converged @ iteration: 136
# Weights: [ 6.         -4.65247284 -6.61734254]
# Target/Predicted function agree: True
# ======================================================================
# Run #936: successfully converged @ iteration: 38
# Weights: [ 4.         -2.87899989 -3.69832313]
# Target/Predicted function agree: True
# ======================================================================
# Run #937: successfully converged @ iteration: 74
# Weights: [ 2.         -3.1333567  -6.29943458]
# Target/Predicted function agree: True
# ======================================================================
# Run #938: successfully converged @ iteration: 39
# Weights: [ 1.         -4.43293772 -3.08959837]
# Target/Predicted function agree: True
# ======================================================================
# Run #939: successfully converged @ iteration: 46
# Weights: [-2.          2.43941359 -4.90713816]
# Target/Predicted function agree: True
# ======================================================================
# Run #940: successfully converged @ iteration: 80
# Weights: [ 2.         -6.66414922 -4.66231154]
# Target/Predicted function agree: True
# ======================================================================
# Run #941: successfully converged @ iteration: 62
# Weights: [ 4.         -1.96388228 -5.63966918]
# Target/Predicted function agree: True
# ======================================================================
# Run #942: successfully converged @ iteration: 10
# Weights: [ 0.         -2.26148827 -2.04572815]
# Target/Predicted function agree: True
# ======================================================================
# Run #943: successfully converged @ iteration: 78
# Weights: [-2.          5.38582856 -5.96703926]
# Target/Predicted function agree: True
# ======================================================================
# Run #944: successfully converged @ iteration: 38
# Weights: [ 2.          3.63280682 -4.01790043]
# Target/Predicted function agree: True
# ======================================================================
# Run #945: successfully converged @ iteration: 29
# Weights: [ 3.         -3.95718268 -1.11106623]
# Target/Predicted function agree: True
# ======================================================================
# Run #946: successfully converged @ iteration: 5
# Weights: [-1.         -0.4988308  -1.09636492]
# Target/Predicted function agree: True
# ======================================================================
# Run #947: successfully converged @ iteration: 224
# Weights: [ 2.         -8.34314659 -8.47584468]
# Target/Predicted function agree: True
# ======================================================================
# Run #948: successfully converged @ iteration: 47
# Weights: [-3.          0.81742436 -4.68168404]
# Target/Predicted function agree: True
# ======================================================================
# Run #949: successfully converged @ iteration: 89
# Weights: [-3.         -3.40158051 -7.54337082]
# Target/Predicted function agree: True
# ======================================================================
# Run #950: successfully converged @ iteration: 166
# Weights: [ 2.         -5.42879868 -9.78768692]
# Target/Predicted function agree: True
# ======================================================================
# Run #951: successfully converged @ iteration: 21
# Weights: [-1.         -0.21342357 -3.70910259]
# Target/Predicted function agree: True
# ======================================================================
# Run #952: successfully converged @ iteration: 9
# Weights: [ 1.          0.70216312 -1.97572454]
# Target/Predicted function agree: True
# ======================================================================
# Run #953: successfully converged @ iteration: 21
# Weights: [-1.          3.08538134 -1.6733348 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #954: successfully converged @ iteration: 19
# Weights: [ 1.          2.83295626 -2.65152373]
# Target/Predicted function agree: True
# ======================================================================
# Run #955: successfully converged @ iteration: 43
# Weights: [ 3.         -3.09046669 -4.59060606]
# Target/Predicted function agree: True
# ======================================================================
# Run #956: successfully converged @ iteration: 20
# Weights: [-2.          0.93570317 -3.236516  ]
# Target/Predicted function agree: True
# ======================================================================
# Run #957: successfully converged @ iteration: 35
# Weights: [ 1.         -3.33352422 -3.71914876]
# Target/Predicted function agree: True
# ======================================================================
# Run #958: successfully converged @ iteration: 29
# Weights: [-3.         -1.14460954 -4.34856872]
# Target/Predicted function agree: True
# ======================================================================
# Run #959: successfully converged @ iteration: 79
# Weights: [-1.          3.63929267 -6.81338432]
# Target/Predicted function agree: True
# ======================================================================
# Run #960: successfully converged @ iteration: 217
# Weights: [-1.         -6.69499894 -9.22858535]
# Target/Predicted function agree: True
# ======================================================================
# Run #961: successfully converged @ iteration: 390
# Weights: [-10.           1.32081495 -14.43085539]
# Target/Predicted function agree: True
# ======================================================================
# Run #962: successfully converged @ iteration: 67
# Weights: [-3.         -1.52618039 -7.16498111]
# Target/Predicted function agree: True
# ======================================================================
# Run #963: successfully converged @ iteration: 11
# Weights: [-1.          0.21430798 -2.47631579]
# Target/Predicted function agree: True
# ======================================================================
# Run #964: successfully converged @ iteration: 68
# Weights: [ 2.          6.27742314 -3.10372931]
# Target/Predicted function agree: True
# ======================================================================
# Run #965: successfully converged @ iteration: 109
# Weights: [-1.          6.20738409 -7.89251561]
# Target/Predicted function agree: True
# ======================================================================
# Run #966: successfully converged @ iteration: 21
# Weights: [-1.         -2.85131583 -1.72501471]
# Target/Predicted function agree: True
# ======================================================================
# Run #967: successfully converged @ iteration: 501
# Weights: [ -1.           7.63864739 -14.71939334]
# Target/Predicted function agree: True
# ======================================================================
# Run #968: successfully converged @ iteration: 108
# Weights: [-2.          6.37410197 -5.70501292]
# Target/Predicted function agree: True
# ======================================================================
# Run #969: successfully converged @ iteration: 89
# Weights: [ 1.          7.80161777 -1.73567375]
# Target/Predicted function agree: True
# ======================================================================
# Run #970: successfully converged @ iteration: 59
# Weights: [ 1.          4.69752298 -3.01430254]
# Target/Predicted function agree: True
# ======================================================================
# Run #971: successfully converged @ iteration: 154
# Weights: [ 2.          8.50747702 -4.93716623]
# Target/Predicted function agree: True
# ======================================================================
# Run #972: successfully converged @ iteration: 35
# Weights: [-3.          4.48118338 -1.1938494 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #973: successfully converged @ iteration: 153
# Weights: [-1.          9.62241322 -5.87919042]
# Target/Predicted function agree: True
# ======================================================================
# Run #974: successfully converged @ iteration: 32
# Weights: [-4.          3.25721743 -1.45957764]
# Target/Predicted function agree: True
# ======================================================================
# Run #975: successfully converged @ iteration: 88
# Weights: [-2.          7.918604   -0.53681171]
# Target/Predicted function agree: True
# ======================================================================
# Run #976: successfully converged @ iteration: 87
# Weights: [ 3.          7.39136624 -3.09558471]
# Target/Predicted function agree: True
# ======================================================================
# Run #977: successfully converged @ iteration: 57
# Weights: [-3.         -5.42082915 -0.5601451 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #978: successfully converged @ iteration: 370
# Weights: [ -2.          12.40789447 -11.26866837]
# Target/Predicted function agree: True
# ======================================================================
# Run #979: successfully converged @ iteration: 26
# Weights: [ 0.         -3.81144997 -0.91299982]
# Target/Predicted function agree: True
# ======================================================================
# Run #980: successfully converged @ iteration: 14
# Weights: [ 2.          1.98199318 -2.13736379]
# Target/Predicted function agree: True
# ======================================================================
# Run #981: successfully converged @ iteration: 123
# Weights: [-5.        -8.3355425 -0.935091 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #982: successfully converged @ iteration: 142
# Weights: [ 2.          8.77905298 -5.21699191]
# Target/Predicted function agree: True
# ======================================================================
# Run #983: successfully converged @ iteration: 97
# Weights: [ 1.          3.52601329 -8.05586638]
# Target/Predicted function agree: True
# ======================================================================
# Run #984: successfully converged @ iteration: 22
# Weights: [-2.          3.11715536 -0.08022112]
# Target/Predicted function agree: True
# ======================================================================
# Run #985: successfully converged @ iteration: 211
# Weights: [ 1.          9.60214611 -8.79294948]
# Target/Predicted function agree: True
# ======================================================================
# Run #986: successfully converged @ iteration: 14
# Weights: [ 0.         -3.29715597 -1.50570284]
# Target/Predicted function agree: True
# ======================================================================
# Run #987: successfully converged @ iteration: 112
# Weights: [-2.         -7.22610389 -6.72555152]
# Target/Predicted function agree: True
# ======================================================================
# Run #988: successfully converged @ iteration: 155
# Weights: [-1.         -8.12289033 -7.62945835]
# Target/Predicted function agree: True
# ======================================================================
# Run #989: successfully converged @ iteration: 173
# Weights: [ 1.          8.92248398 -7.09415355]
# Target/Predicted function agree: True
# ======================================================================
# Run #990: successfully converged @ iteration: 329
# Weights: [ -5.          11.87329222  -7.2587925 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #991: successfully converged @ iteration: 258
# Weights: [-10.           0.19855688 -11.25153995]
# Target/Predicted function agree: True
# ======================================================================
# Run #992: successfully converged @ iteration: 232
# Weights: [ -4.         -12.57936652  -1.0886914 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #993: successfully converged @ iteration: 180
# Weights: [ 6.          2.58005997 -8.35388142]
# Target/Predicted function agree: True
# ======================================================================
# Run #994: successfully converged @ iteration: 128
# Weights: [ 2.         -8.81176967 -1.71198202]
# Target/Predicted function agree: True
# ======================================================================
# Run #995: successfully converged @ iteration: 5
# Weights: [-1.          0.41954954 -2.1535779 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #996: successfully converged @ iteration: 30
# Weights: [-2.         -1.12086806 -4.44209267]
# Target/Predicted function agree: True
# ======================================================================
# Run #997: successfully converged @ iteration: 261
# Weights: [ -1.         -6.7479059 -10.8792891]
# Target/Predicted function agree: True
# ======================================================================
# Run #998: successfully converged @ iteration: 308
# Weights: [ -6.         -12.95955877  -0.28297867]
# Target/Predicted function agree: True
# ======================================================================
# Run #999: successfully converged @ iteration: 25
# Weights: [-1.          1.59045797 -5.0024064 ]
# Target/Predicted function agree: True
# ======================================================================
# Run #1000: successfully converged @ iteration: 55
# Weights: [ 3.         -5.97026505 -1.06745975]
# Target/Predicted function agree: True
# ======================================================================
# Avg. iteration to succussfully converged: 110
# Probabily that f and g will disagree on their classfication of a random point: 0.0070
